# %%
import pandas as pd

# %%
data1 = pd.read_excel("Banka verileri_X2000orj.xlsx")

# %%
data1
# Out:
#                              BANKA\RASYO\2000        00V1       00V2  \
# 0                                      Akbank   14.706635  18.247825
# 1                        Alternatif Bank A.Ş.   10.793131  13.446925
# 2                            Anadolubank A.Ş.    5.280553   5.838857
# 3                      Arap Türk Bankası A.Ş.    8.303480   9.335769
# 4                           Bank Ekspres A.Ş.  -41.502912 -30.569562
# 5                      Bank Kapital Türk A.Ş. -300.887180 -90.498552
# 6                           Bayındırbank A.Ş.   14.123705  17.224973
# 7           Birleşik Türk Körfez Bankası A.Ş.   13.765730  17.100155
# 8                               Citibank N.A.   16.204293  21.104977
# 9                            Demirbank T.A.Ş.    7.741709   8.917693
# 10                             Denizbank A.Ş.   14.148617  18.334468
# 11                               Egebank A.Ş.  -52.090370 -37.667242
# 12                   Eskişehir Bankası T.A.Ş.  -23.429579 -22.556010
# ...

# %%
data2 = data1[["00V1","00V2","00V3","00V5","00V7","00V9","00V15","00V16"]]

# %%
data2
# Out:
#           00V1       00V2        00V3       00V5       00V7       00V9  \
# 0    14.706635  18.247825   12.201029  35.744739   7.882845  62.325934
# 1    10.793131  13.446925    5.828228  39.740475   4.964902  62.336819
# 2     5.280553   5.838857    2.712216  23.884281  10.907227  67.742658
# 3     8.303480   9.335769    4.742442  12.699995   3.773190  89.690284
# 4   -41.502912 -30.569562  -46.696799  36.538072  32.998596  20.612697
# 5  -300.887180 -90.498552 -321.064616   9.867205  20.177436  19.027308
# 6    14.123705  17.224973    5.505406  20.678587   8.618299  72.067421
# 7    13.765730  17.100155    8.226175  20.325116   5.585990  84.471681
# 8    16.204293  21.104977   13.977497  20.637887   3.138580  93.064054
# 9     7.741709   8.917693   -0.701863  49.225741  12.965748  41.308439
# 10   14.148617  18.334468    5.240159  33.992060  32.872315  32.888307
# 11  -52.090370 -37.667242  -57.678871  13.250004   5.590514  55.464238
# ...

# %%
data2.describe().T
# Out:
#        count       mean        std         min        25%         50%  \
# 00V1    41.0  -8.814061  55.464493 -300.887180  -8.893348    8.569176
# 00V2    41.0   2.339947  28.436840  -90.498552  -9.531924    9.868142
# 00V3    41.0 -17.594140  57.420863 -321.064616 -15.133977    1.363980
# 00V5    41.0  29.926088  17.191903    0.417507  20.325116   28.828147
# 00V7    41.0  17.119009  11.766005    1.266792   7.713198   14.702960
# 00V9    41.0  49.301245  21.566368    7.390813  34.702990   46.460717
# 00V15   41.0  -6.896210  69.919438 -151.151979 -56.469110    1.942442
# 00V16   41.0  83.893010  57.277311  -73.576381  55.990055  104.761573
#
#               75%         max
# 00V1    14.123705   33.110463
# 00V2    17.224973   53.115666
# 00V3     5.740728   20.291967
# 00V5    39.216030   86.711242
# 00V7    22.811559   51.167434
# 00V9    62.336819   93.064054
# 00V15   59.559938  121.975905
# 00V16  122.830274  170.411271

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data2.corr(), annot=True)
plt.show()

# %%
#1
sns.pairplot(data2)
plt.show()

# %%
#1
data2.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'00V1'}>,
#         <AxesSubplot:title={'center':'00V2'}>,
#         <AxesSubplot:title={'center':'00V3'}>],
#        [<AxesSubplot:title={'center':'00V5'}>,
#         <AxesSubplot:title={'center':'00V7'}>,
#         <AxesSubplot:title={'center':'00V9'}>],
#        [<AxesSubplot:title={'center':'00V15'}>,
#         <AxesSubplot:title={'center':'00V16'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(data2)

# p değerini değerlendirin
alpha = 0.05
if p > alpha:
    print('Veri normal dağılmıştır (p = %.3f)' % p)
else:
    print('Veri normal dağılmamıştır (p = %.3f)' % p)
# Out:
# Veri normal dağılmamıştır (p = 0.000)

# %%
print(p)
# Out:
# 2.1187762610749058e-15

# %%
import numpy as np
import pandas as pd

# %%
#2
dataeksik= pd.read_excel("eksik_data2.xlsx")
dataeksik
# Out:
#           00V1       00V2        00V3       00V5       00V7       00V9  \
# 0    14.706635  18.247825   12.201029  35.744739   7.882845  62.325934
# 1    10.793131  13.446925    5.828228  39.740475   4.964902  62.336819
# 2     5.280553   5.838857    2.712216  23.884281  10.907227  67.742658
# 3     8.303480   9.335769         NaN  12.699995   3.773190  89.690284
# 4   -41.502912 -30.569562  -46.696799  36.538072        NaN  20.612697
# 5          NaN -90.498552 -321.064616   9.867205  20.177436  19.027308
# 6    14.123705        NaN         NaN  20.678587   8.618299  72.067421
# 7    13.765730  17.100155    8.226175  20.325116   5.585990        NaN
# 8    16.204293  21.104977   13.977497        NaN   3.138580  93.064054
# 9     7.741709   8.917693   -0.701863  49.225741  12.965748  41.308439
# 10         NaN  18.334468    5.240159        NaN  32.872315  32.888307
# 11  -52.090370 -37.667242  -57.678871  13.250004   5.590514  55.464238
# ...

# %%
#2
dataeksik.isnull().sum()
# Out:
# 00V1     5
# 00V2     6
# 00V3     6
# 00V5     7
# 00V7     9
# 00V9     2
# 00V15    6
# 00V16    3
# dtype: int64

# %%
#2
total_cells = np.product(dataeksik.shape)
total_missing = dataeksik.isnull().sum().sum()
print("Toplam Eksik Veri: %",(total_missing/total_cells)*100)
# Out:
# Toplam Eksik Veri: % 13.414634146341465

# %%
#4
from scipy import stats
V7 = data2.iloc[:,7]
stats.probplot(V7, dist="norm", plot=plt)
plt.show()

# %%
from scipy.stats import shapiro
import numpy as np

# %%
#4
data2["değişken_karekök"] =np.sqrt(data2["00V7"])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5976\3564473479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["değişken_karekök"] =np.sqrt(data2["00V7"])

# %%
#SQUARE- ROOT TRANSFORMATİON YÖNTEMİ-4
stat, p = shapiro(data2["değişken_karekök"])
if p> 0.05:
    print("Veri kümesi normal dağılım gösterir.".format(p))
else:
    print("Veri kümesi normal dağılım göstermez.".format(p))
# Out:
# Veri kümesi normal dağılım gösterir.

# %%
#4
stats.probplot(data2["değişken_karekök"], dist= "norm", plot= plt)
plt.show()
